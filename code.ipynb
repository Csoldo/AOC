# %% [markdown]
# ## DAY 1

# %%
with open('input1.txt') as f:
    lines = f.readlines()

# numbers = []
# sum = 0
# for word in lines:
#     current = []
#     for letter in word:
#         if letter.isdigit():
#             current.append(letter)
#     if len(current) > 0:
#         sum += int(current[0]) * 10 + int(current[len(current) - 1])

# print(sum)


#------------------------ Part two
nums = ["one", "two", "three", "four", "five", "six", "seven", "eight", "nine"]

sum = 0
for word in lines:
    current = []
    for i, letter in enumerate(word):
        if letter.isdigit():
            current.append(letter)
        
        for d, val in enumerate(nums):
            if word[i:].startswith(val):
                current.append(str(d+1))

    sum += int(current[0]+current[-1])

print(sum)

# %% [markdown]
# ## DAY 2

# %%
with open('input1.txt') as f:
    lines = f.readlines()

sum = 0
for line in lines:
    blues = 0
    reds = 0
    greens = 0
    words = line.split(" ")
    valid = True
    for i, value in enumerate(words):
        if value.__contains__("blue"):
            blues += int(words[i-1])
        if value.__contains__("red"):
            reds += int(words[i-1])
        if value.__contains__("green"):
            greens += int(words[i-1])
  
        if reds > 12 or greens > 13 or blues > 14:
            valid = False
            break
        if value.__contains__(";"):
            blues = 0
            reds = 0
            greens = 0

    if valid:
        sum += int(words[1].split(":")[0])
print(sum)


#----- PART 2

sum = 0
for line in lines:
    blues = 0
    reds = 0
    greens = 0
    words = line.split(" ")
    max_blue = 0
    max_red = 0
    max_green = 0
    print(words)
    for i, value in enumerate(words):
        if value.__contains__("blue"):
            blues += int(words[i-1])
        if value.__contains__("red"):
            reds += int(words[i-1])
        if value.__contains__("green"):
            greens += int(words[i-1])
  
        if value.__contains__(";") or value.__contains__("\n"):
            max_blue = blues if max_blue < blues else max_blue 
            max_red = reds if max_red < reds else max_red 
            max_green = greens if max_green < greens else max_green
            # print(f"val: {value}, blues: {max_blue}, reds: {max_red}, greens: {max_green}")
            blues = 0
            reds = 0
            greens = 0

    sum += max_green * max_blue * max_red
    print(f"sum: {sum}, blues: {max_blue}, reds: {max_red}, greens: {max_green}")
print(sum)

# %% [markdown]
# ## DAY 3

# %%
import numpy as np
with open('tmp.txt') as f:
    lines = f.read().splitlines() 
sum = 0
lines = np.asarray(lines)
for i, line in enumerate(lines):
    for j, c in enumerate(line):
        if not c.isdigit() and not c == "." and not c == "\n":
            search_min = j - 1 if j > 0 else 0
            search_max = j + 1 if j < len(lines) - 1 else len(lines) - 1
            search_vertical_min = i - 1 if i > 0 else 0
            search_vertical_max = i + 1 if i < len(lines) - 1 else len(lines) - 1
            number_str = ""
            print(f"X: min: {search_min}, max: {search_max}\nY: min{search_vertical_min}, max: {search_vertical_max}")
            for k in range(search_vertical_min, search_vertical_max+1):
                for l in range(search_min, search_max+1):
                    if lines[k][l].isdigit():
                        number_start = l
                        number_str = ""
                        while lines[k][number_start].isdigit() and number_start > -1:
                            number_start -= 1
                        number_start += 1
                        while lines[k][number_start].isdigit() and number_start < len(line) -1:
                            number_str += lines[k][number_start]
                            string_list = list(lines[k])
                            string_list[number_start] = "."
                            lines[k] = "".join(string_list)
                            number_start += 1
                        sum += int(number_str)
                        break
            # print(lines)
            # print(f"i,j: {i},{j} , sum: {sum} num: {number_str}:")    
                    
print(sum)

# %%
from collections import defaultdict
with open('in.txt') as f:
    lines = f.read() 
lines = lines.split('\n')
G = [[c for c in line] for line in lines]
R = len(G)
C = len(G[0])

p1 = 0
nums = defaultdict(list)
for r in range(len(G)):
  gears = set()
  n = 0
  has_part = False
  for c in range(len(G[r])+1):
    if c<C and G[r][c].isdigit():
      n = n*10+int(G[r][c])
      for rr in [-1,0,1]:
        for cc in [-1,0,1]:
          if 0<=r+rr<R and 0<=c+cc<C:
            ch = G[r+rr][c+cc]
            if not ch.isdigit() and ch != '.':
              has_part = True
            if ch=='*':
              gears.add((r+rr, c+cc))
    elif n>0:
      for gear in gears:
        nums[gear].append(n)
      if has_part:
        p1 += n
      n = 0
      has_part = False
      gears = set()

print(p1)
p2 = 0
for k,v in nums.items():
  if len(v)==2:
    p2 += v[0]*v[1]
print(p2)

# %% [markdown]
# ## DAY 4

# %%
with open('in.txt') as f:
    lines = f.read() 
lines = lines.split('\n')
formatted_lines = []
for line in lines: 
    formatted_lines.append(line.split(":")[1])

# Solution 1
sum = 0
for card in formatted_lines:
    winning_numbers = card.split("|")[0].split()
    numbers = card.split("|")[1].split()
    wins = 0
    for num in numbers:
        if winning_numbers.__contains__(num):
            wins += 1

    if wins > 0:
        sum += 2**(wins-1)
print(sum)

# Solution 2
number_of_cards = len(formatted_lines)
copies = []
for i in range(number_of_cards):
    copies.append(0)

for i, card in enumerate(formatted_lines):
    winning_numbers = card.split("|")[0].split()
    numbers = card.split("|")[1].split()
    wins = 0
    for num in numbers:
        if winning_numbers.__contains__(num):
            wins += 1
    if wins > 0:
        for j in range(i+1, i+1+wins):
            if j < number_of_cards:
                copies[j] += 1 + copies[i]
print(copies)
sum = number_of_cards
for val in copies:
    sum += val
print(sum)

# %% [markdown]
# ## DAY 5

# %%
with open('in.txt') as f:
    lines = f.read() 
lines = lines.split('\n')

seeds = [int(x) for x in lines[0].split(":")[1].split()]
values_dict = {}
size_limit = len(lines)

i = 2
while i < size_limit:
    map_key = lines[i].split()[0]
    i += 1
    values_dict[map_key] = []
    while lines[i] != "":
        values_dict[map_key].append([int(x) for x in lines[i].split()])
        i += 1
    i += 1


# print(values_dict)
locations = []
for i, seed_index in enumerate(seeds):
    if i % 2 == 1: 
        continue
    for seed in range(seed_index, seed_index + seeds[i+1]):
        current_map = seed
        for map_value in values_dict:
            for map in values_dict[map_value]:
                dest = map[0]
                source = map[1]
                shift = map[2]
                if current_map >= source and current_map < source + shift:
                    diff = dest - source
                    current_map += diff
                    break
            # print(f"seed: {seed}, map: {current_map}")

        locations.append(current_map)

print(locations)
print(min(locations))

# %% [markdown]
# ## DAY 6

# %%
with open('in.txt') as f:
    lines = f.read() 
lines = lines.split('\n')

# PART 1
times = [int(x) for x in lines[0].split(":")[1].split()]
records = [int(x) for x in lines[1].split(":")[1].split()]

print(times)

product = 1
for i, time in enumerate(times):
    record = records[i]
    cnt = 0
    for k in range(1, time-1):
        dist = k * (time - k)
        if dist > record:
            cnt += 1
    if cnt > 0:
        product *= cnt

print(product)

# PART 2
times = lines[0].split(":")[1].split()
records = lines[1].split(":")[1].split()
time = int("".join(times))
record = int("".join(records))
product = 1
cnt = 0
for k in range(1, time-1):
    dist = k * (time - k)
    if dist > record:
        cnt += 1
if cnt > 0:
    product *= cnt

print(product)

#440000
#26187338

# %% [markdown]
# ## DAY 7

# %%
with open("in.txt") as f:
    lines = f.read() 
lines = lines.split('\n')

hands = []
bids = []
for line in lines:
    hands.append(line.split()[0])
    bids.append(int(line.split()[1]))

point_maps = {
    "T": 10,
    "J": 11,
    "Q": 12,
    "K": 13,
    "A": 14
}

def get_hand_points(hand: str):
    hist = [0] * 13
    for card in hand:
        if card.isdigit():
            hist[int(card)-2] += 1
        else:
            hist[point_maps[card]-2] += 1
    
    hist.sort(reverse=True)
    if hist[0] == 5:
        return 6
    elif hist[0] == 4:
        return 5
    elif hist[0] == 3 and hist[1] == 2:
        return 4
    elif hist[0] == 3:
        return 3
    elif hist[0] == 2 and hist[1] == 2:
        return 2
    elif hist[0] == 2:
        return 1
    return 0

def compare_cards(card_a: str, card_b: str):
    card_a_points = get_hand_points(card_a)
    card_b_points = get_hand_points(card_b)
    if card_a_points == card_b_points:
        for i in range(5):
                value_a = int(card_a[i]) if card_a[i].isdigit() else point_maps[card_a[i]]
                value_b = int(card_b[i]) if card_b[i].isdigit() else point_maps[card_b[i]]
                if value_a != value_b:
                    return value_a > value_b
                
    else:
        return card_a_points > card_b_points
    
ranks = []
size = len(hands)
for i, hand in enumerate(hands):
    hands_beaten = 0
    for j in range(size):
        if compare_cards(hand, hands[j]):
            hands_beaten += 1
    ranks.append(hands_beaten+1)

print(ranks)

sum = 0
for i in range(size):
    sum += ranks[i] * bids[i]

print(sum)
# Out:
# [513, 282, 914, 54, 334, 257, 512, 204, 750, 817, 221, 644, 696, 300, 250, 866, 933, 305, 973, 223, 268, 897, 498, 834, 293, 501, 814, 683, 418, 188, 434, 141, 200, 616, 273, 708, 662, 920, 163, 339, 145, 823, 40, 727, 454, 569, 71, 634, 843, 549, 323, 229, 994, 898, 679, 62, 767, 854, 343, 735, 494, 307, 419, 892, 372, 417, 155, 692, 584, 441, 137, 356, 453, 861, 107, 433, 64, 775, 443, 131, 173, 529, 563, 737, 527, 133, 915, 839, 801, 865, 665, 230, 875, 445, 465, 347, 555, 546, 931, 987, 947, 63, 463, 810, 254, 624, 38, 228, 202, 218, 55, 319, 36, 2, 766, 479, 91, 476, 421, 227, 170, 298, 446, 235, 975, 422, 75, 550, 285, 542, 536, 386, 969, 944, 545, 588, 776, 837, 369, 43, 388, 205, 929, 942, 502, 566, 20, 378, 471, 985, 503, 894, 611, 753, 557, 162, 648, 748, 938, 7, 518, 995, 738, 149, 760, 144, 617, 605, 749, 867, 514, 399, 123, 895, 207, 552, 440, 916, 15, 196, 310, 225, 669, 104, 759, 880, 681, 217, 129, 764, 943, 639, 836, 525, 928, 480, 990, 342, 98, 14, 554, 224, 873, 428, 705, 350, 391, 968, 955, 345, 337, 666, 790, 663, 201, 435, 883, 729, 50, 193, 304, 725, 449, 405, 732, 53, 13, 862, 35, 167, 583, 780, 829, 77, 848, 425, 232, 959, 869, 946, 83, 134, 216, 213, 115, 478, 344, 255, 26, 722, 153, 222, 535, 807, 90, 219, 961, 580, 847, 457, 889, 609, 348, 261, 333, 288, 127, 600, 258, 475, 927, 958, 37, 640, 710, 180, 689, 855, 394, 497, 664, 291, 290, 531, 819, 560, 505, 668, 885, 675, 413, 118, 168, 172, 917, 244,